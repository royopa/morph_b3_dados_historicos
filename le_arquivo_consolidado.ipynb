# %%
import os
import pandas as pd

# %%
df = pd.read_csv('base_completa.csv')
df
# Out:
#         TIPREG        DATA  CODBDI    CODNEG  TPMERC       NOMRES      ESPECI  \
# 0            1  2020-01-02       2     AALR3      10       ALLIAR  ON      NM
# 1            1  2020-01-02       2    AAPL34      10        APPLE         DRN
# 2            1  2020-01-02       2     ABCB4      10   ABC BRASIL  PN  EJ  N2
# 3            1  2020-01-02       2     ABEV3      10    AMBEV S/A      ON  EJ
# 4            1  2020-01-02       2     ADHM3      10  ADVANCED-DH          ON
# ...        ...         ...     ...       ...     ...          ...         ...
# 878139       1  2020-09-29      82  YDUQW320      80        YDUQE  ON      NM
# 878140       1  2020-09-29      82  YDUQV252      80        YDUQE  ON      NM
# 878141       1  2020-09-29      82  YDUQV267      80    YDUQE  FM  ON      NM
# 878142       1  2020-09-29      82  YDUQV275      80        YDUQE  ON      NM
# 878143       1  2020-09-29      82  YDUQV280      80    YDUQE  FM  ON      NM
#
# ...

# %%
df['DATA'].value_counts().min()
# Out:
# 3530

# %%
df['DATA'].value_counts().max()
# Out:
# 6483

# %%
df.head()
# Out:
#    TIPREG        DATA  CODBDI  CODNEG  TPMERC       NOMRES      ESPECI  \
# 0       1  2020-01-02       2   AALR3      10       ALLIAR  ON      NM
# 1       1  2020-01-02       2  AAPL34      10        APPLE         DRN
# 2       1  2020-01-02       2   ABCB4      10   ABC BRASIL  PN  EJ  N2
# 3       1  2020-01-02       2   ABEV3      10    AMBEV S/A      ON  EJ
# 4       1  2020-01-02       2   ADHM3      10  ADVANCED-DH          ON
#
#    PRAZOT MODREF   PREABE  ...  TOTNEG    QUATOT        VOLTOT  PREEXE  \
# 0     NaN     R$   1829.0  ...    2443    585800  1.094620e+09     0.0
# 1     NaN     R$  12000.0  ...       9     12700  1.533380e+08     0.0
# 2     NaN     R$   2000.0  ...    3979    870400  1.745788e+09     0.0
# 3     NaN     R$   1886.0  ...   31581  16011300  3.062348e+10     0.0
# 4     NaN     R$    255.0  ...     307    193400  4.719270e+07     0.0
#
#    INDOPC    DATVEN  FATCOT  PTOEXE        CODISI  DISMES
# ...

# %%
df.tail()
# Out:
#         TIPREG        DATA  CODBDI    CODNEG  TPMERC     NOMRES      ESPECI  \
# 878139       1  2020-09-29      82  YDUQW320      80      YDUQE  ON      NM
# 878140       1  2020-09-29      82  YDUQV252      80      YDUQE  ON      NM
# 878141       1  2020-09-29      82  YDUQV267      80  YDUQE  FM  ON      NM
# 878142       1  2020-09-29      82  YDUQV275      80      YDUQE  ON      NM
# 878143       1  2020-09-29      82  YDUQV280      80  YDUQE  FM  ON      NM
#
#         PRAZOT MODREF  PREABE  ...  TOTNEG  QUATOT     VOLTOT  PREEXE  INDOPC  \
# 878139     0.0     R$   515.0  ...       4    2400  1271400.0  3200.0       0
# 878140     0.0     R$    52.0  ...       1     100     5200.0  2525.0       0
# 878141     0.0     R$   107.0  ...       4   30200  3189600.0  2675.0       0
# 878142     0.0     R$   142.0  ...      29   37700  5353700.0  2750.0       0
# 878143     0.0     R$   171.0  ...       2    2000   339800.0  2800.0       0
#
# ...
